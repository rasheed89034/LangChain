# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
embeddings = (
    OllamaEmbeddings(model="embeddinggemma") ## default 
)

# %%
embeddings
# Out:
# OllamaEmbeddings(base_url='http://localhost:11434', model='embeddinggemma', embed_instruction='passage: ', query_instruction='query: ', mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None, show_progress=False, headers=None, model_kwargs=None)

# %%
text = embeddings.embed_documents(
    [
        "My Name is Rasheed Ahmad",
        "Student of AI at Comsats University Islamabad Attock Campus",
        "And My Current Semester is 5th"
    ]
)

# %%
text
# Out:
# [[-0.1432700753211975,
#   0.05485984683036804,
#   0.02626071125268936,
#   -0.045552436262369156,
#   -0.06529699265956879,
#   -0.006813505198806524,
#   0.031860318034887314,
#   -0.015618884935975075,
#   -0.03315875306725502,
#   -0.029315799474716187,
#   -0.03393981605768204,
#   -0.021776827052235603,
#   -0.02365829423069954,
#   -0.0359170064330101,
#   0.08071603626012802,
#   0.027730006724596024,
#   0.020694291219115257,
#   -0.0387435257434845,
#   -0.08919019252061844,
#   -0.029278885573148727,
#   0.0034481650218367577,
#   -0.055556148290634155,
#   -0.04001156613230705,
#   0.015907829627394676,
#   0.018289143219590187,
#   0.009646035730838776,
#   0.013133600354194641,
#   -0.02725304290652275,
#   0.023724881932139397,
#   0.03797222673892975,
#   0.034274209290742874,
#   -0.022849341854453087,
#   0.017127618193626404,
#   0.004142332822084427,
#   -0.02140859328210354,
#   0.05469188839197159,
#   -0.01611221395432949,
#   -0.008867847733199596,
# ...

# %%
len(text[0])
# Out:
# 768

# %%
embeddings.embed_query("What is the University name?")
# Out:
# [-0.09731732308864594,
#  0.009613844566047192,
#  0.02282821014523506,
#  0.030513949692249298,
#  0.026434635743498802,
#  0.01769244484603405,
#  0.04895218461751938,
#  0.01001027598977089,
#  -0.050289053469896317,
#  -0.002436000620946288,
#  0.0035425545647740364,
#  0.00738005805760622,
#  0.03390324115753174,
#  -0.01724998652935028,
#  0.1395592987537384,
#  0.02733907848596573,
#  0.01445628609508276,
#  -0.0063636451959609985,
#  -0.05211932212114334,
#  -0.00027631456032395363,
#  0.0761943906545639,
#  -0.031499460339546204,
#  -0.013223674148321152,
#  -0.0008034053607843816,
#  0.014181552454829216,
#  0.05333947017788887,
#  -0.007340624928474426,
#  -0.03949235752224922,
#  -0.0370481014251709,
#  0.06700681895017624,
#  0.03636389970779419,
#  -0.029897700995206833,
#  0.008987064473330975,
#  0.017587216570973396,
#  -0.014287948608398438,
#  0.09157265722751617,
#  0.0012825271114706993,
#  -0.0666140466928482,
#  -0.02929438091814518,
#  -0.0299138855189085,
# ...
